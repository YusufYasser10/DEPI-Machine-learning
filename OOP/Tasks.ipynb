# %% [markdown]
#   12- Create a Class for a Student Write a Python class called Student with the following attributes: name: A string representing the student's name. age: An integer representing the student's age. grades: A list of integers representing the grades the student has received. The class should have the following methods: add_grade(grade): This method should add a grade to the grades list. average_grade(): This method should return the average of the student's grades. is_passing(): This method should return True if the student's average grade is greater than or equal to 60, and False otherwise.

# %% [markdown]
#   13- Create a Class for a Rectangle Write a Python class called Rectangle with the following attributes: length: A float representing the length of the rectangle. width: A float representing the width of the rectangle. The class should have the following methods: area(): This method should return the area of the rectangle (length * width). perimeter(): This method should return the perimeter of the rectangle (2 * (length + width))

# %% [markdown]
#   14- Create a Class for a Car Write a Python class called Car with the following attributes: make: A string representing the make of the car. model: A string representing the model of the car. year: An integer representing the year of the car. mileage: A float representing the mileage of the car in miles. The class should have the following methods: display_info(): This method should print the car's information in a readable format. drive(miles): This method should add the specified number of miles to the car's mileage

# %% [markdown]
# 15- Inheritance Question Write a Python class called Animal with attributes name and age. The class should have a method speak() that prints "Animal makes a sound." Then, write a subclass called Dog that overrides speak() to print "Woof!"

# %% [markdown]
# 16- Encapsulation Question Write a Python class called Account with a private attribute balance. Include methods deposit(amount), withdraw(amount), and get_balance(). Ensure balance is only accessible through these methods

# %% [markdown]
# 17- Polymorphism Question Create a base class Shape with a method area() returning None. Create subclasses Rectangle and Circle that override area(). Write a function print_area(shape) that prints the area of any Shape object
